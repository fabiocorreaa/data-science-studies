# %%
import pandas as pd

# %%
# Lendo arquivo csv
dados = pd.read_csv("Olympics.csv")
dados.shape
# Out:
# (147, 15)

# %%
# Resumo estatístico de colunas numéricas
dados.describe()
# Out:
#          № Summer         01 !         02 !         03 !         Total  \
# count  147.000000   147.000000   147.000000   147.000000    147.000000
# mean    13.476190    65.428571    64.965986    69.795918    200.190476
# std      7.072359   405.549990   399.309960   427.187344   1231.306297
# min      1.000000     0.000000     0.000000     0.000000      0.000000
# 25%      8.000000     0.000000     1.000000     1.000000      2.000000
# 50%     13.000000     3.000000     4.000000     6.000000     12.000000
# 75%     18.500000    24.000000    28.000000    29.000000     86.000000
# max     27.000000  4809.000000  4775.000000  5130.000000  14714.000000
#
#          № Winter      01 !.1      02 !.1      03 !.1      Total.1  \
# count  147.000000  147.000000  147.000000  147.000000   147.000000
# mean     6.700680   13.047619   13.034014   12.897959    38.979592
# std      7.433186   80.799204   80.634421   79.588388   240.917324
# ...

# %%
# Head
dados.head(8)
# Out:
#                            № Summer  01 !  02 !  03 !  Total  № Winter  \
# Afghanistan (AFG)                13     0     0     2      2         0
# Algeria (ALG)                    12     5     2     8     15         3
# Argentina (ARG)                  23    18    24    28     70        18
# Armenia (ARM)                     5     1     2     9     12         6
# Australasia (ANZ) [ANZ]           2     3     4     5     12         0
# Australia (AUS) [AUS] [Z]        25   139   152   177    468        18
# Austria (AUT)                    26    18    33    35     86        22
# Azerbaijan (AZE)                  5     6     5    15     26         5
#
#                            01 !.1  02 !.1  03 !.1  Total.1  № Games  01 !.2  \
# Afghanistan (AFG)               0       0       0        0       13       0
# Algeria (ALG)                   0       0       0        0       15       5
# Argentina (ARG)                 0       0       0        0       41      18
# ...

# %%
# Tail
dados.tail(8)
# Out:
#                                               № Summer  01 !  02 !  03 !  \
# Vietnam (VIE)                                       14     0     2     0
# Virgin Islands (ISV)                                11     0     1     0
# Yugoslavia (YUG) [YUG]                              16    26    29    28
# Independent Olympic Participants (IOP) [IOP]         1     0     1     2
# Zambia (ZAM) [ZAM]                                  12     0     1     1
# Zimbabwe (ZIM) [ZIM]                                12     3     4     1
# Mixed team (ZZX) [ZZX]                               3     8     5     4
# Totals                                              27  4809  4775  5130
#
#                                               Total  № Winter  01 !.1  02 !.1  \
# Vietnam (VIE)                                     2         0       0       0
# Virgin Islands (ISV)                              1         7       0       0
# ...

# %%
# Filtrando por coluna
dados[["№ Games"]].describe()
# Out:
#           № Games
# count  147.000000
# mean    20.176871
# std     13.257048
# min      1.000000
# 25%     11.000000
# 50%     15.000000
# 75%     27.000000
# max     49.000000

# %%
# Filtrar linhas por índice
dados.loc['Afghanistan (AFG)':'Australasia (ANZ) [ANZ]']
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Algeria (ALG)                  12     5     2     8     15         3       0
# Argentina (ARG)                23    18    24    28     70        18       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Algeria (ALG)                 0       0        0       15       5       2
# Argentina (ARG)               0       0        0       41      18      24
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
#
#                          03 !.2  Combined total
# ...

# %%
# Selecionando linhas
dados.loc[['Australasia (ANZ) [ANZ]', 'Independent Olympic Participants (IOP) [IOP]']]
# Out:
#                                               № Summer  01 !  02 !  03 !  \
# Australasia (ANZ) [ANZ]                              2     3     4     5
# Independent Olympic Participants (IOP) [IOP]         1     0     1     2
#
#                                               Total  № Winter  01 !.1  02 !.1  \
# Australasia (ANZ) [ANZ]                          12         0       0       0
# Independent Olympic Participants (IOP) [IOP]      3         0       0       0
#
#                                               03 !.1  Total.1  № Games  \
# Australasia (ANZ) [ANZ]                            0        0        2
# Independent Olympic Participants (IOP) [IOP]       0        0        1
#
#                                               01 !.2  02 !.2  03 !.2  \
# Australasia (ANZ) [ANZ]                            3       4       5
# Independent Olympic Participants (IOP) [IOP]       0       1       2
#
#                                               Combined total
# ...

# %%
# Filtrando
dados.loc[dados['№ Summer'] >= 20].head(5)
# Out:
#                            № Summer  01 !  02 !  03 !  Total  № Winter  \
# Argentina (ARG)                  23    18    24    28     70        18
# Australia (AUS) [AUS] [Z]        25   139   152   177    468        18
# Austria (AUT)                    26    18    33    35     86        22
# Belgium (BEL)                    25    37    52    53    142        20
# Brazil (BRA)                     21    23    30    55    108         7
#
#                            01 !.1  02 !.1  03 !.1  Total.1  № Games  01 !.2  \
# Argentina (ARG)                 0       0       0        0       41      18
# Australia (AUS) [AUS] [Z]       5       3       4       12       43     144
# Austria (AUT)                  59      78      81      218       48      77
# Belgium (BEL)                   1       1       3        5       45      38
# Brazil (BRA)                    0       0       0        0       28      23
#
#                            02 !.2  03 !.2  Combined total
# ...

# %%
# Criando outro df a partir de variável com condição
menor = dados.loc[dados['01 !'] < 5].head(5)
menor
# Out:
#                          № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)              13     0     0     2      2         0       0
# Armenia (ARM)                   5     1     2     9     12         6       0
# Australasia (ANZ) [ANZ]         2     3     4     5     12         0       0
# Bahrain (BRN)                   8     0     0     1      1         0       0
# Barbados (BAR) [BAR]           11     0     0     1      1         0       0
#
#                          02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  \
# Afghanistan (AFG)             0       0        0       13       0       0
# Armenia (ARM)                 0       0        0       11       1       2
# Australasia (ANZ) [ANZ]       0       0        0        2       3       4
# Bahrain (BRN)                 0       0        0        8       0       0
# Barbados (BAR) [BAR]          0       0        0       11       0       0
#
#                          03 !.2  Combined total
# ...

# %%
especifico = dados[['№ Summer', 'Total']].loc[dados['01 !'] < 5].head(8)
especifico
# Out:
#                          № Summer  Total
# Afghanistan (AFG)              13      2
# Armenia (ARM)                   5     12
# Australasia (ANZ) [ANZ]         2     12
# Bahrain (BRN)                   8      1
# Barbados (BAR) [BAR]           11      1
# Bermuda (BER)                  17      1
# Bohemia (BOH) [BOH] [Z]         3      4
# Botswana (BOT)                  9      1

# %%
# Séries, única coluna
# Pode ser importado array do numpy
s1 = pd.Series([2,5,3,34,54,23,1,16])
print(s1)
# Out:
# 0     2
# 1     5
# 2     3
# 3    34
# 4    54
# 5    23
# 6     1
# 7    16
# dtype: int64

# %%
# Tipo da série
s2 = dados['01 !']
print(s2)
type(s2)
# Out:
# Afghanistan (AFG)                                  0
# Algeria (ALG)                                      5
# Argentina (ARG)                                   18
# Armenia (ARM)                                      1
# Australasia (ANZ) [ANZ]                            3
#                                                 ...
# Independent Olympic Participants (IOP) [IOP]       0
# Zambia (ZAM) [ZAM]                                 0
# Zimbabwe (ZIM) [ZIM]                               3
# Mixed team (ZZX) [ZZX]                             8
# Totals                                          4809
# Name: 01 !, Length: 147, dtype: int64
# pandas.core.series.Series

# %%
# Tipo do dataframe
d4 = dados[['01 !']]
type(d4)
# Out:
# pandas.core.frame.DataFrame

# %%
# Renomear colunas
dados.rename(columns=({'01 !': 'Zero-One'}))
# Out:
#                                               № Summer  Zero-One  02 !  03 !  \
# Afghanistan (AFG)                                   13         0     0     2
# Algeria (ALG)                                       12         5     2     8
# Argentina (ARG)                                     23        18    24    28
# Armenia (ARM)                                        5         1     2     9
# Australasia (ANZ) [ANZ]                              2         3     4     5
# ...                                                ...       ...   ...   ...
# Independent Olympic Participants (IOP) [IOP]         1         0     1     2
# Zambia (ZAM) [ZAM]                                  12         0     1     1
# Zimbabwe (ZIM) [ZIM]                                12         3     4     1
# Mixed team (ZZX) [ZZX]                               3         8     5     4
# Totals                                              27      4809  4775  5130
#
# ...

# %%
dados.head(3)
# Out:
#                    № Summer  01 !  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)        13     0     0     2      2         0       0
# Algeria (ALG)            12     5     2     8     15         3       0
# Argentina (ARG)          23    18    24    28     70        18       0
#
#                    02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  03 !.2  \
# Afghanistan (AFG)       0       0        0       13       0       0       2
# Algeria (ALG)           0       0        0       15       5       2       8
# Argentina (ARG)         0       0        0       41      18      24      28
#
#                    Combined total
# Afghanistan (AFG)               2
# Algeria (ALG)                  15
# Argentina (ARG)                70

# %%
dados.rename(columns=({'01 !': 'Zero-One'}), inplace=True)

# %%
dados.head(3)
# Out:
#                    № Summer  Zero-One  02 !  03 !  Total  № Winter  01 !.1  \
# Afghanistan (AFG)        13         0     0     2      2         0       0
# Algeria (ALG)            12         5     2     8     15         3       0
# Argentina (ARG)          23        18    24    28     70        18       0
#
#                    02 !.1  03 !.1  Total.1  № Games  01 !.2  02 !.2  03 !.2  \
# Afghanistan (AFG)       0       0        0       13       0       0       2
# Algeria (ALG)           0       0        0       15       5       2       8
# Argentina (ARG)         0       0        0       41      18      24      28
#
#                    Combined total
# Afghanistan (AFG)               2
# Algeria (ALG)                  15
# Argentina (ARG)                70

# %%
dados.drop('01 !.1', axis=1, inplace=True)
dados
# Out:
#                                               № Summer  Zero-One  02 !  03 !  \
# Afghanistan (AFG)                                   13         0     0     2
# Algeria (ALG)                                       12         5     2     8
# Argentina (ARG)                                     23        18    24    28
# Armenia (ARM)                                        5         1     2     9
# Australasia (ANZ) [ANZ]                              2         3     4     5
# ...                                                ...       ...   ...   ...
# Independent Olympic Participants (IOP) [IOP]         1         0     1     2
# Zambia (ZAM) [ZAM]                                  12         0     1     1
# Zimbabwe (ZIM) [ZIM]                                12         3     4     1
# Mixed team (ZZX) [ZZX]                               3         8     5     4
# Totals                                              27      4809  4775  5130
#
# ...

# %%
# Verificar dados nulos
dados.isnull()
# Out:
#                                               № Summer  Zero-One   02 !  \
# Afghanistan (AFG)                                False     False  False
# Algeria (ALG)                                    False     False  False
# Argentina (ARG)                                  False     False  False
# Armenia (ARM)                                    False     False  False
# Australasia (ANZ) [ANZ]                          False     False  False
# ...                                                ...       ...    ...
# Independent Olympic Participants (IOP) [IOP]     False     False  False
# Zambia (ZAM) [ZAM]                               False     False  False
# Zimbabwe (ZIM) [ZIM]                             False     False  False
# Mixed team (ZZX) [ZZX]                           False     False  False
# Totals                                           False     False  False
#
#                                                03 !  Total  № Winter  02 !.1  \
# ...

# %%
# Verificar dados nulos pt 2
dados.isnull().sum()
# Out:
# № Summer          0
# Zero-One          0
# 02 !              0
# 03 !              0
# Total             0
# № Winter          0
# 02 !.1            0
# 03 !.1            0
# Total.1           0
# № Games           0
# 01 !.2            0
# 02 !.2            0
# 03 !.2            0
# Combined total    0
# dtype: int64

# %%
# Retirar colunas com NaN
dados.dropna()
# Out:
#                                               № Summer  Zero-One  02 !  03 !  \
# Afghanistan (AFG)                                   13         0     0     2
# Algeria (ALG)                                       12         5     2     8
# Argentina (ARG)                                     23        18    24    28
# Armenia (ARM)                                        5         1     2     9
# Australasia (ANZ) [ANZ]                              2         3     4     5
# ...                                                ...       ...   ...   ...
# Independent Olympic Participants (IOP) [IOP]         1         0     1     2
# Zambia (ZAM) [ZAM]                                  12         0     1     1
# Zimbabwe (ZIM) [ZIM]                                12         3     4     1
# Mixed team (ZZX) [ZZX]                               3         8     5     4
# Totals                                              27      4809  4775  5130
#
# ...

# %%
#iloc - selecionando o número de colunas e linhas
dados.iloc[0:3,0:5]
# Out:
#                    № Summer  Zero-One  02 !  03 !  Total
# Afghanistan (AFG)        13         0     0     2      2
# Algeria (ALG)            12         5     2     8     15
# Argentina (ARG)          23        18    24    28     70

# %%
dados.iloc[[0,1,2,3,7],0:5]
# Out:
#                    № Summer  Zero-One  02 !  03 !  Total
# Afghanistan (AFG)        13         0     0     2      2
# Algeria (ALG)            12         5     2     8     15
# Argentina (ARG)          23        18    24    28     70
# Armenia (ARM)             5         1     2     9     12
# Azerbaijan (AZE)          5         6     5    15     26
